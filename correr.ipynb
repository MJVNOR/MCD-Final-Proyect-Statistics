# %%
# %conda install -c conda-forge streamlit
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.
# Retrieving notices: ...working... done
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\te490718\AppData\Local\miniconda3\envs\JP_ETL
#
#   added / updated specs:
#     - streamlit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     abseil-cpp-20211102.0      |       h0e60522_0         2.3 MB  conda-forge
#     altair-4.2.2               |     pyhd8ed1ab_0         544 KB  conda-forge
#     arrow-cpp-11.0.0           |   py38h3577439_0         7.2 MB
#     aws-c-common-0.4.57        |       ha925a31_1         147 KB
#     aws-c-event-stream-0.1.6   |       hd77b12b_5          26 KB
#     aws-checksums-0.1.9        |       ha925a31_0          50 KB
#     aws-sdk-cpp-1.8.185        |       hd77b12b_0         2.5 MB
# ...
